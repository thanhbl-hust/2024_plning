# %%
print("Hello World 2024!")
# Out:
# Hello World 2024!

# %%
#pip --version
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
def findMaxandMin(ls):
    maxIncrease = -10
    inroot1 = -1
    inroot2 = -1
    maxDecrease = -10
    deroot1 = -1
    deroot2 = -1
    for i in range(1, len(ls)):
        if ls[i] > ls[i - 1]:
            if ls[i] - ls[i - 1] > maxIncrease:
                maxIncrease = ls[i] - ls[i - 1]
                inroot1 = i - 1
                inroot2 = i 
        elif ls[i] < ls[i - 1]:
            if ls[i - 1] - ls[i] > maxDecrease:
                maxDecrease = ls[i - 1] - ls[i]
                deroot1 = i - 1
                deroot2 = i
    return maxIncrease, maxDecrease, inroot1, inroot2, deroot1, deroot2

# %%
#data
w = [
    84.3,  83.2,   82.8,   82.0,   82.7,   81.6,   82.6,   81.5,
    82,    81.5,   81.8,   81.3,   81.5,   81.5,   81.6,   80.7,
    81.3,  81.1,   80.6,   80.3,   80.7,   80.1,   80.3,   80.3,
    79.9,  79.2,   80,     79.5,   80,     79.4,   79.9,   79.5,
    79.6,  79,     78.8,   78.1,   78.2,   77.7,   78.3,   78.3,
    78.7,  78.1,   78.1,   77.9,   78.5,   79.7,   79.1,   78.6,
    78.8,  78.1,   78.2,   77.6,   77.9,   77.4,   77.9,   77.4,
    77.6,  77.4,   77.7,   77.7,   77.8,   76.6,   77.1,   77.2,
    77.3,  76.8,   76.9,   77.4,   77.6,   77.2,   76.9,   76.7,
    76.8,  76.5,   76.5,   76.1,   75.9,   76.1,   75.6,   75.2,
    75.9,  75.3,   75.5,   75,     75.9,   75.5,   75.5,   75.3,
    76.4,  75.8,   76.6,   76.2,   75.9,   75.8,   76,     75.1,
    75.5,  75.1,   75,     75.5,   75.8,   75.5,   76.3,   76.5,
    76.8,  76.4,   76.8,   76.5,   76.2,   76.5,   76.6,   77.1,
    78.1,  77.5,   78.5,   78,     77.5,   77.6,   78,     77.5,
    79.1,  78.3,   77.9,   78.1,   78.2,   78.4,   80,     79.2,
    78.2,  78.4,   79.6,   79.5,   79.1,   79.1,   79.5,   79.2,
    79.5,  79.5,   80.2,   79.9,   80.4,   81,     80.4,   80.4,
    80.6,  80.2,   80.5,   80,     80.2,   79.9,   80.4,   80.2,
    80.4,  80.4,   79.9,   80.4,   80,     79.8,   79.9,   79.6,
    80,    80,     79.5,   79.3,   80,     79.8,   79.8,   79.8,
    80.6,  80.6,   80,     79.9,   79.4,   79.1,   79.6,   79.2,
    79.4,  79,     79.6,   79.5,   80,     79.8,   80.3,   80.2,
    80.2,  80.3,   79.5,   79.5,   79.3,   79.2,   79.3,   79.3,
    79.1,  78.7,   79,     78.7,   78.8,   79.6,   79.8,   79.2,
    79.2,  78.6,   78.2,   78.1,   78.5,   77.9,   79.1,   78.6,
    78.9,  78.6,   78.4,   77.8,   77.6,   77.8,   77.9,   77.4,
    77.6,  76.8,   77.1,   77,     77.9,   77.1,   77.7,   77.5,
    77.9,  77.6,   77.7,   77.6,   77.5,   77.2,   77.3,   77.2,
    77,    76.8,   78,     78.9,   78.9,   77.8,   78.2,   77.8,
    78.8,  77.9,   78.4,   77.4,   78.2,   78,     77.9,   77.5,
    77.3,  77.2,   76.9,   76.8,   77.2,   77.5,   77.1,   77.2,
    77.7,  77.8,   77.9,   78.2,   78.2,   78,     78.1,   77.7,
    77.7,  77.4,   77.3,   77.1,   77.2,   77.4,   77.6,   77.2,
    76.8,  76.7,   77,     76.8,   76.5,   76.1,   76.5,   76.2,
    75.6,  76.2,   76,     75.7,   76.3,   76,     76,     76.1,
    76,    75.6,   76.3,   75.3,   75.7,   75.8,   76,     75.2, 
    75.6,  75.6,   76.1,   75.7,   75.5,   75.4,   76,     76.2,
    76.9,  76.7,   76.7,   76.7,   76.6,   76.8,   77.7,   78.4,
    77,    77.2,   77.5,   77.3,   77.3,   77.1,   77.4,   77.1,
    77.5,  77.5,   76.9,   77.1,   77.3,   77.7,   78.1,   77.7,
    77.3,  77.7,   77.7,   78.2,   78.3,   78,     78,     77.9,
    78.4,  78.4,   78.1,   78.5,   78,     77.7,   76.8,   76.8, 
    76.8,  77,     76.6,   76.7,   76.2,   75.6,   76.2,   75.8,
    76.5,  76.5,   76.5,   76.5,   76.7,   77,     77.1,   77.4,
    76.8,  77,     76.1,   76.3,   76.9,   77.1,   78.3,   77.9,
    77.4,  77.5,   77.4,   77.1,   77.1,   76.9,   76.7,   76,
    75.3,  76.1,   76.7,   76.3,   76.1,   76.5,   77.1,   77,
    76.7,  76.9,   76.3,   76,     76.5,   76.5,   76.1,   75.6,
    75.7,  75.9,   76.1,   75.9,   75.9,   75.9,   76.1,   75.7,
    75.7,  75.4,   75.9,   75.9,   75.7,   75.4,   75.3,   74.9,
    75.4

]

d = [
    '13/1 N', '14/1 D', '14/1 N', '15/1 D', '15/1 N', '16/1 D', '16/1 N', '17/1 D',
    '17/1 N', '18/1 D', '18/1 N', '19/1 D', '19/1 N', '20/1 D', '20/1 N', '21/1 D',
    '21/1 N', '22/1 D', '22/1 N', '23/1 D', '23/1 N', '24/1 D', '24/1 N', '25/1 D',
    '25/1 N', '26/1 D', '26/1 N', '27/1 D', '27/1 N', '28/1 D', '28/1 N', '29/1 D',
    '29/1 N', '30/1 D', '30/1 N', '31/1 D', '31/1 N',  '1/2 D',  '1/2 N',  '2/2 D',
     '2/2 N',  '3/2 D',  '3/2 N',  '4/2 D',  '4/2 N',  '5/2 D',  '5/2 N',  '6/2 D',
     '6/2 N',  '7/2 D',  '7/2 N',  '8/2 D',  '8/2 N',  '9/2 D',  '9/2 N', '10/2 D',
    '10/2 N', '11/2 D', '11/2 N', '12/2 D', '12/2 N', '13/2 D', '13/2 N', '14/2 D',
    '14/2 N', '15/2 D', '15/2 N', '16/2 D', '16/2 N', '17/2 D', '17/2 N', '18/2 D',
    '18/2 N', '19/2 D', '19/2 N', '20/2 D', '20/2 N', '21/2 D', '21/2 N', '22/2 D',
    '22/2 N', '23/2 D', '23/2 N', '24/2 D', '24/2 N', '25/2 D', '25/2 N', '26/2 D',
    '26/2 N', '27/2 D', '27/2 N', '28/2 D', '28/2 N', '29/2 D', '29/2 N',  '1/3 D',
     '1/3 N',  '2/3 D',  '2/3 N',  '3/3 D',  '3/3 N',  '4/3 D',  '4/3 N',  '5/3 D',
     '5/3 N',  '6/3 D',  '6/3 N',  '7/3 D',  '7/3 N',  '8/3 D',  '8/3 N',  '9/3 D',
     '9/3 N', '10/3 D', '10/3 N', '11/3 D', '11/3 N', '12/3 D', '12/3 N', '13/3 D',
    '13/3 N', '14/3 D', '14/3 N', '15/3 D', '15/3 N', '16/3 D', '16/3 N', '17/3 D',
    '17/3 N', '18/3 D', '18/3 N', '19/3 D', '19/3 N', '20/3 D', '20/3 N', '21/3 D',
    '21/3 N', '22/3 D', '22/3 N', '23/3 D', '23/3 N', '24/3 D', '24/3 N', '25/3 D',
    '25/3 N', '26/3 D', '26/3 N', '27/3 D', '27/3 N', '28/3 D', '28/3 N', '29/3 D',
    '29/3 N', '30/3 D', '30/3 N', '31/3 D', '31/3 N',  '1/4 D',  '1/4 N',  '2/4 D',
     '2/4 N',  '3/4 D',  '3/4 N',  '4/4 D',  '4/4 N',  '5/4 D',  '5/4 N',  '6/4 D',
     '6/4 N',  '7/4 D',  '7/4 N',  '8/4 D',  '8/4 N',  '9/4 D',  '9/4 N', '10/4 D',
    '10/4 N', '11/4 D', '11/4 N', '12/4 D', '12/4 N', '13/4 D', '13/4 N', '14/4 D',
    '14/4 N', '15/4 D', '15/4 N', '16/4 D', '16/4 N', '17/4 D', '17/4 N', '18/4 D',
    '18/4 N', '19/4 D', '19/4 N', '20/4 D', '20/4 N', '21/4 D', '21/4 N', '22/4 D',
    '22/4 N', '23/4 D', '23/4 N', '24/4 D', '24/4 N', '25/4 D', '25/4 N', '26/4 D',
    '26/4 N', '27/4 D', '27/4 N', '28/4 D', '28/4 N', '29/4 D', '29/4 N', '30/4 D',
    '30/4 N',  '1/5 D',  '1/5 N',  '2/5 D',  '2/5 N',  '3/5 D',  '3/5 N',  '4/5 D',
     '4/5 N',  '5/5 D',  '5/5 N',  '6/5 D',  '6/5 N',  '7/5 D',  '7/5 N',  '8/5 D',
     '8/5 N',  '9/5 D',  '9/5 N', '10/5 D', '10/5 N', '11/5 D', '11/5 N', '12/5 D',
    '12/5 N', '13/5 D', '13/5 N', '14/5 D', '14/5 N', '15/5 D', '15/5 N', '16/5 D',
    '16/5 N', '17/5 D', '17/5 N', '18/5 D', '18/5 N', '19/5 D', '19/5 N', '20/5 D',
    '20/5 N', '21/5 D', '21/5 N', '22/5 D', '22/5 N', '23/5 D', '23/5 N', '24/5 D',
    '24/5 N', '25/5 D', '25/5 N', '26/5 D', '26/5 N', '27/5 D', '27/5 N', '28/5 D',
    '28/5 N', '29/5 D', '29/5 N', '30/5 D', '30/5 N', '31/5 D', '31/5 N',  '1/6 D',
     '1/6 N',  '2/6 D',  '2/6 N',  '3/6 D',  '3/6 N',  '4/6 D',  '4/6 N',  '5/6 D',
     '5/6 N',  '6/6 D',  '6/6 N',  '7/6 D',  '7/6 N',  '8/6 D',  '8/6 N',  '9/6 D',
     '9/6 N', '10/6 D', '10/6 N', '11/6 D', '11/6 N', '12/6 D', '12/6 N', '13/6 D', 
    '13/6 N', '14/6 D', '14/6 N', '15/6 D', '15/6 N', '16/6 D', '16/6 N', '17/6 D',
    '17/6 N', '18/6 D', '18/6 N', '19/6 D', '19/6 N', '20/6 D', '20/6 N', '21/6 D',
    '21/6 N', '22/6 D', '22/6 N', '23/6 D', '23/6 N', '24/6 D', '24/6 N', '25/6 D',
    '25/6 N', '26/6 D', '26/6 N', '27/6 D', '27/6 N', '28/6 D', '28/6 N', '29/6 D',
    '29/6 N', '30/6 D', '30/6 N',  '1/7 D',  '1/7 N',  '2/7 D',  '2/7 N',  '3/7 D',
     '3/7 N',  '4/7 D',  '4/7 N',  '5/7 D',  '5/7 N',  '6/7 D',  '6/7 N',  '7/7 D',
     '7/7 N',  '8/7 D',  '8/7 N',  '9/7 D',  '9/7 N', '10/7 D', '10/7 N', '11/7 D',
    '11/7 N', '12/7 D', '12/7 N', '13/7 D', '13/7 N', '14/7 D', '14/7 N', '15/7 D',
    '15/7 N', '16/7 D', '16/7 N', '17/7 D', '17/7 N', '18/7 D', '18/7 N', '19/7 D', 
    '19/7 N', '20/7 D', '20/7 N', '21/7 D', '21/7 N', '22/7 D', '22/7 N', '23/7 D',
    '23/7 N', '24/7 D', '24/7 N', '25/7 D', '25/7 N', '26/7 D', '26/7 N', '27/7 D',
    '27/7 N', '28/7 D', '28/7 N', '29/7 D', '29/7 N', '30/7 D', '30/7 N', '31/7 D',
    '31/7 N',  '1/8 D',  '1/8 N',  '2/8 D',  '2/8 N',  '3/8 D',  '3/8 N',  '4/8 D',
     '4/8 N'
]

# %%
def paint(w, d, set_time):


    times = set_time
    times_appear = len(d) / times
    times_appear = int(times_appear)
    n = len(w)
    average_values = []
    for i in range(0, n, times_appear):
        average = np.mean(w[i: i + times_appear])
        average_values.append(average)
    x_ticks = range(0, n, times_appear)
    x_labels = [d[i] for i in x_ticks]

    max_value = np.max(w)
    min_value = np.min(w)

    #oneday has 2 parameters, 0:00 and after wake up
    maxIn, maxDe, inr1, inr2, der1, der2 = findMaxandMin(w)

    print("INF OF PROCESS:")
    print("\n")
    print(f'Day of process: {int((len(w) + len(w) % 2) / 2)} days')
    print(f'From: {d[0]} to now: {d[len(d) - 1]}')
    print(f'Max weight in process: {round(max(w), 2)} (kg)')
    print(f'Min weight in process: {round(min(w), 2)} (kg)')
    print(f'Max increase in one process: {round(maxIn, 1)}___date:{d[inr1]} - {d[inr2]} ({w[inr1]} to {w[inr2]})')
    print(f'Max decrease in one process: {round(maxDe, 2)}___date:{d[der1]} - {d[der2]} ({w[der1]} to {w[der2]})')
    print(f'Total weight decrease: {round(abs(w[len(w) - 1] - w[0]), 1)} kg after {len(w) - 1} process ({w[0]} - {w[len(w) - 1]}).')

    print('\n')

    print(f'Training process started: 15/7 Day!')

    fig = plt.figure(figsize=(12, 8))
    plt.axhline(y = max_value, color = 'r', linestyle = '--', label = 'Max')
    plt.axhline(y = min_value, color = 'y', linestyle = '--', label = 'Min')

    plt.axhline(y = 68, color = 'g', linestyle = '--', label = 'Expected')

    plt.plot(d, w, marker = '')
    plt.xlabel('Time (D: day, N: night)')
    plt.ylabel('W (kg)')
    plt.title('W by Ds')
    plt.xticks(x_ticks, x_labels, rotation = 45)
    plt.legend(['max weight reached', 'min weight reached'], loc = 'lower left')
    plt.show()


check = len(w)
paint(w[:check], d[:check], 11)
# Out:
# INF OF PROCESS:
#
#
# Day of process: 205 days
# From: 13/1 N to now: 4/8 N
# Max weight in process: 84.3 (kg)
# Min weight in process: 74.9 (kg)
# Max increase in one process: 1.6___date:13/3 D - 13/3 N (77.5 to 79.1)
# Max decrease in one process: 1.4___date:17/6 D - 17/6 N (78.4 to 77)
# Total weight decrease: 8.9 kg after 408 process (84.3 - 75.4).
#
#
# Training process started: 15/7 Day!
